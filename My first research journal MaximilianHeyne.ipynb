# %% [markdown]
# # Research Notebook
# ## Maximilian Heyne
# ## Date: Jan. 20. - 27.

# %% [markdown]
# # 1: Experience
#
# - read more about linux commands
# - learn how to manuver around in Niagara cluster
# - set up a vertual enviermont in my owen directory
# - write and run code to plot Stellar Mass vs Black Hole Mass
#
#
# ## Motivation:
#
# To be able to properly work in computational Astrophysics research, I had to read and learn a lot about Linux commands [1], how to log in to a computing cluster and maneuver around, how to compile and extract data, and how to copy and move files. Basically, learning the first steps how to work in Science.
#
# With the acquired knowledge, I had to reproduce the plot from figure 4 of the paper. [2].

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# With the other EXPLORE students in my group, we have been writing a code to make a plot of Stellar mass vs. Black hole mass using the StellarMassfunktion and the program that was given to us by Professor Kannahn.
# The plot should then be compared to the plot from a paper [2], which has previously been covered in a journal talk by one of the EXPLORE students.
# We had to copy the program from Professor Kannahn's directory to our own.
# Therefore, I used the copy command to do so.
# Once the file had been copied, I had to set up a virtual environment to be able to run the program properly. It is important to have the necessary software and the compatible version installed in the virtual environment.
#
# Then I added the program shown below to generate the plot.

# %%
plt.figure()
plt.xscale('log')
plt.yscale('log')
plt.scatter(stmass*1e10/0.6774, bhmass*1e10/0.6774)
plt.xlabel("Stellar Mass (Log)")
plt.ylabel("BH Mass (Log)")
plt.title("Stellar Mass vs BH Mass")
plt.grid()
plt.savefig("StellarMassfkt.png")
plt.show()

# %% [markdown]
# ![StellarMassfkt.png](attachment:StellarMassfkt.png)

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# The plot shows similarities with the one from the paper [2], but it is still too imprecise to clearly differentiate, for example, the levels of redshift. It also does not include observational data from the JWST.
# Here, more work is required to create a properly comparable plot, which will involve working with formulas 7 & 8 from the paper. [2]

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# Plan for the upcoming week is:
#
# - Getting more familiar with submitting jobs on the Niagara cluster.
#
# - Creating 5 more plots with different data inputs:   - Stellar mass vs. Halo mass
#     - Stellar mass vs. Gas mass
#     - Black hole mass vs. Gas mass
#     - Metallicity vs. Stellar mass
#     - Star formation vs. Stellar mass
#
# - Running a job on the Niagara cluster and creating the same 5 plots with the results.

# %% [markdown]
# # 5. Bibliography
#
# [1]https://www.doc.ic.ac.uk/~wjk/UnixIntro/
#
# [2]https://arxiv.org/pdf/2401.04159
